# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,10,200)

# %%
x
# Out:
# array([ 0.        ,  0.05025126,  0.10050251,  0.15075377,  0.20100503,
#         0.25125628,  0.30150754,  0.35175879,  0.40201005,  0.45226131,
#         0.50251256,  0.55276382,  0.60301508,  0.65326633,  0.70351759,
#         0.75376884,  0.8040201 ,  0.85427136,  0.90452261,  0.95477387,
#         1.00502513,  1.05527638,  1.10552764,  1.15577889,  1.20603015,
#         1.25628141,  1.30653266,  1.35678392,  1.40703518,  1.45728643,
#         1.50753769,  1.55778894,  1.6080402 ,  1.65829146,  1.70854271,
#         1.75879397,  1.80904523,  1.85929648,  1.90954774,  1.95979899,
#         2.01005025,  2.06030151,  2.11055276,  2.16080402,  2.21105528,
#         2.26130653,  2.31155779,  2.36180905,  2.4120603 ,  2.46231156,
#         2.51256281,  2.56281407,  2.61306533,  2.66331658,  2.71356784,
#         2.7638191 ,  2.81407035,  2.86432161,  2.91457286,  2.96482412,
#         3.01507538,  3.06532663,  3.11557789,  3.16582915,  3.2160804 ,
# ...

# %%
y = np.sin(x)

# %%
y
# Out:
# array([ 0.        ,  0.05023011,  0.10033341,  0.15018339,  0.19965422,
#         0.24862099,  0.29696008,  0.34454944,  0.39126893,  0.43700061,
#         0.481629  ,  0.52504145,  0.56712835,  0.60778345,  0.6469041 ,
#         0.68439153,  0.72015112,  0.75409257,  0.78613019,  0.8161831 ,
#         0.84417544,  0.87003651,  0.89370105,  0.91510929,  0.9342072 ,
#         0.95094655,  0.96528509,  0.97718662,  0.98662108,  0.99356467,
#         0.99799984,  0.99991541,  0.99930653,  0.99617474,  0.99052796,
#         0.98238043,  0.97175273,  0.95867168,  0.94317032,  0.92528777,
#         0.90506919,  0.88256563,  0.85783388,  0.8309364 ,  0.80194109,
#         0.77092115,  0.7379549 ,  0.70312557,  0.66652108,  0.62823386,
#         0.58836056,  0.54700186,  0.50426216,  0.46024937,  0.41507461,
#         0.36885193,  0.32169803,  0.27373195,  0.22507478,  0.17584939,
#         0.12618003,  0.07619211,  0.02601183, -0.02423412, -0.07441889,
# ...

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("This is my x data")
plt.ylabel("This is my y data")
plt.title("This is my title")
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.05460055, 0.09197155, 0.95617991, 0.46843492, 0.0207329 ,
#        0.28535331, 0.00221639, 0.12710858, 0.30387702, 0.39816679,
#        0.8431179 , 0.42821333, 0.0613101 , 0.58988977, 0.02302733,
#        0.49607161, 0.11265804, 0.19362819, 0.41671626, 0.25176987,
#        0.14399954, 0.46574318, 0.27788207, 0.73573525, 0.67992479,
#        0.80998613, 0.27088962, 0.22722514, 0.87198287, 0.06808549,
#        0.79199335, 0.25828933, 0.55156963, 0.5298696 , 0.07131188,
#        0.68407522, 0.56548355, 0.68205585, 0.94623692, 0.84629637,
#        0.81769258, 0.94354401, 0.99568354, 0.46159655, 0.30024564,
#        0.69717414, 0.24849551, 0.52720259, 0.01311324, 0.88472206])

# %%
y
# Out:
# array([0.25908496, 0.03016531, 0.05061279, 0.50370419, 0.40938736,
#        0.12053501, 0.85863171, 0.44565275, 0.22320311, 0.20885442,
#        0.87511862, 0.55601905, 0.50720798, 0.79032409, 0.28742857,
#        0.51642527, 0.21958318, 0.29018396, 0.70737884, 0.3476019 ,
#        0.43626617, 0.54198011, 0.80362231, 0.49092827, 0.10053717,
#        0.91719901, 0.77405643, 0.34635858, 0.07481322, 0.10990063,
#        0.8501417 , 0.97928063, 0.3167411 , 0.50037644, 0.65916208,
#        0.52376604, 0.15976339, 0.12689213, 0.98714012, 0.16087426,
#        0.44822866, 0.13950322, 0.37233896, 0.18998079, 0.02248453,
#        0.94081617, 0.11918119, 0.05860135, 0.45961648, 0.74336265])

# %%
plt.scatter(x,y)

# %%
x
# Out:
# array([0.05460055, 0.09197155, 0.95617991, 0.46843492, 0.0207329 ,
#        0.28535331, 0.00221639, 0.12710858, 0.30387702, 0.39816679,
#        0.8431179 , 0.42821333, 0.0613101 , 0.58988977, 0.02302733,
#        0.49607161, 0.11265804, 0.19362819, 0.41671626, 0.25176987,
#        0.14399954, 0.46574318, 0.27788207, 0.73573525, 0.67992479,
#        0.80998613, 0.27088962, 0.22722514, 0.87198287, 0.06808549,
#        0.79199335, 0.25828933, 0.55156963, 0.5298696 , 0.07131188,
#        0.68407522, 0.56548355, 0.68205585, 0.94623692, 0.84629637,
#        0.81769258, 0.94354401, 0.99568354, 0.46159655, 0.30024564,
#        0.69717414, 0.24849551, 0.52720259, 0.01311324, 0.88472206])

# %%
y
# Out:
# array([0.25908496, 0.03016531, 0.05061279, 0.50370419, 0.40938736,
#        0.12053501, 0.85863171, 0.44565275, 0.22320311, 0.20885442,
#        0.87511862, 0.55601905, 0.50720798, 0.79032409, 0.28742857,
#        0.51642527, 0.21958318, 0.29018396, 0.70737884, 0.3476019 ,
#        0.43626617, 0.54198011, 0.80362231, 0.49092827, 0.10053717,
#        0.91719901, 0.77405643, 0.34635858, 0.07481322, 0.10990063,
#        0.8501417 , 0.97928063, 0.3167411 , 0.50037644, 0.65916208,
#        0.52376604, 0.15976339, 0.12689213, 0.98714012, 0.16087426,
#        0.44822866, 0.13950322, 0.37233896, 0.18998079, 0.02248453,
#        0.94081617, 0.11918119, 0.05860135, 0.45961648, 0.74336265])

# %%
plt.scatter(x[0],y[0])

# %%
colours = np.random.rand(50)
plt.scatter(x,y,c = colours)   #c is parameter for colour generation on the basis od random colours values generated

# %%
colours = np.random.rand(50)
sizes = np.random.rand(50) *100
plt.scatter(x,y,c = colours , s = sizes )  #s is size

# %%
#alpha(0 to 1) (tansparent to opaque) is parameter for intensity of colours

# %%
colours = np.random.rand(50)
sizes = np.random.rand(50) *100
plt.scatter(x,y,c = colours , s = sizes , alpha = 0.2 )
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("RANDOM DATA")
# Out:
# Text(0.5, 1.0, 'RANDOM DATA')

# %%
x = ['a' ,'b' , 'c' , 'd' , 'e']

# %%
y = np.random.rand(5)

# %%
plt.plot(x,y)

# %%
plt.bar(x,y)
plt.xlabel("This is X axis")
plt.ylabel("This is Y axis")
plt.title("This is Title")
# Out:
# Text(0.5, 1.0, 'This is Title')

# %%
plt.barh(x,y)    # horizontal bar plot
plt.xlabel("This is X axis")
plt.ylabel("This is Y axis")
plt.title("This is Title")
# Out:
# Text(0.5, 1.0, 'This is Title')

# %%
x = np.linspace(0,10,200)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,'bo')

# %%
plt.plot(x,y,'--r')

# %%
plt.plot(x,y,'-r')

# %%
plt.plot(x,y,'r:.')

# %%
plt.plot(x,y,'k')

# %%
plt.figure(figsize = (6,2))
plt.plot(x,y,'--b')

# %%
plt.figure(figsize=(2,5))
plt.plot(x,y,'--b')

# %%
plt.grid()

# %%
plt.figure(figsize = (6,2))
plt.plot(x,y,'--b')
plt.grid()
plt.show()

# %%
plt.grid()
plt.figure(figsize = (6,2))
plt.plot(x,y,'--b')

plt.show()

# %%
X = np.random.rand(50)
Y = np.random.rand(50)
plt.scatter(X,Y,c = 'r')

# %%
X = np.random.rand(50)
Y = np.random.rand(50)
plt.scatter(X,Y,c = '#98BE7F')   #https://htmlcolorcodes.com/

# %%
X = np.random.rand(50)
Y = np.random.rand(50)
plt.scatter(X,Y,c = '#98BE7F',marker='x')   #https://htmlcolorcodes.com/

# %%
X = np.random.rand(50)
Y = np.random.rand(50)
plt.scatter(X,Y,c = '#98BE7F',marker='X')   #https://htmlcolorcodes.com/

# %%
X = np.random.rand(50)
Y = np.random.rand(50)
plt.scatter(X,Y,c = '#98BE7F',marker='v')   #https://htmlcolorcodes.com/

# %%
x = [2,3,4,5,6,7]
y = [8,9,10,11,12,13]
plt.plot(x,y)

# %%
x = [2,3,4,5,6,7]
y = [8,15,10,11,19,13]
plt.plot(x,y)

# %%
x = [2,3,4,5,6,7]
y = [8,15,10,11,19,13]
plt.scatter(x,y,marker='*')

# %%
data = [1,2,3,4,5,1,2,3,6,7,8,9,1,2]

# %%
plt.hist(data)
plt.show()

# %%
plt.hist(data)
# Out:
# (array([3., 3., 2., 1., 0., 1., 1., 1., 1., 1.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
x = [2,3,4,5,6,7]
y = [8,15,10,11,19,13]
colour = ['red','blue',"#4348DD","#DD9343","#DD9343","#DD9343"] 
plt.scatter(x,y, c = colour)
plt.show()

# %%
x = np.random.rand(50)

# %%
y= np.random.rand(50)

# %%
z = np.random.rand(50)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z)
plt.xlabel("This is x axis")
plt.ylabel("This is y axis")
#plt.zlabel("This is z axis")   #this command is not listed in python
plt.show()
